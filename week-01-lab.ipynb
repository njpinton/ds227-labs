# %% [markdown]
# # DS 227 &middot; Knowledge Discovery in Data &mdash; Week 1 Welcome Lab### Where you're starting fromThis is **not a test** and it is **not graded**. It exists so I know what the roomalready knows before Week 2, and so you find out now &mdash; not in Week 6 &mdash; whetheranything here is unfamiliar.**How long:** about 30 minutes. **What you need:** a browser. Nothing to install.Work top to bottom. If a cell does not run, that is information too &mdash; write down whatit said and move on. Nobody is expected to finish the Stretch section.

# %% [markdown]
# ---## Part 0 &middot; Does this thing workClick the cell below and press **Shift+Enter**.You are not expected to understand the code. You are expected to be able to run it.

# %%
import ioimport pandas as pd# A small, deliberately messy, INVENTED dataset. These are not real figures and should# never be cited — the flaws in it are there on purpose, for you to find.raw = """clinic,barangay,month,visits,staffC-01,Lahug,January,412,6C-02,Mabolo,January,388,5C-03,Guadalupe,January,1240,6C-04,Talamban,January,,4C-05,Banilad,January,455,5C-01,Lahug,February,430,6C-02,Mabolo,February,401,5C-03,Guadalupe,February,97,6C-04,Talamban,February,362,4C-05,Banilad,February,449,0"""df = pd.read_csv(io.StringIO(raw))print("Rows:", len(df), " Columns:", list(df.columns))df

# %% [markdown]
# ---## Part 1 &middot; Look at it properlyLook at the table above before reading on. Take a minute; this is the actual skill.**Answer here** (double-click to edit):1. One clinic has a **missing** value. Which one, and in which column?   &rarr; *your answer*2. Clinic **C-03** reports 1240 visits in January and 97 in February. Give **two   different explanations** that could produce that, one boring and one interesting.   &rarr; *your answer*3. Clinic **C-05** reports 449 visits in February with **0 staff**. What do you think   actually happened?   &rarr; *your answer*

# %% [markdown]
# ---## Part 2 &middot; A claim that does not holdRun the cell, then read the claim under it.

# %%
avg = df["visits"].mean()print(f"Average monthly visits per clinic: {avg:.1f}")

# %% [markdown]
# > **The claim:** *"Clinics in this area average roughly 470 visits a month, so a new> clinic should be resourced for about 470."***Answer here:**1. Name **one** thing wrong with using this average the way the claim does.   &rarr; *your answer*2. The average was computed from the `visits` column. One row had no value at all.   What did the code do with that row &mdash; and did the claim account for it?   &rarr; *your answer*3. What would you want to know before repeating this number to someone who will spend   money based on it?   &rarr; *your answer*

# %% [markdown]
# ---## Part 3 &middot; Frame a questionHalf of this course is deciding what a dataset can and cannot answer.**Answer here:**1. Write **one question** this table could honestly answer.   &rarr; *your answer*2. Write **one question** it looks like it could answer but cannot, and say why.   &rarr; *your answer*

# %% [markdown]
# ---## Part 4 &middot; What you have used beforeNo wrong answers. Replace each `-` with one of: **never heard of it** / **heard of it** /**used it once or twice** / **use it regularly**.| Tool | You ||---|---|| Excel or Google Sheets | - || Python | - || Jupyter or Colab notebooks | - || pandas | - || SQL | - || Tableau, Power BI, or Looker | - || R, Stata, or SPSS | - |**What field do you come from, and what kind of data does it produce?**&rarr; *your answer***Do you already have a dataset you would like to work with this term?**&rarr; *your answer*

# %% [markdown]
# ---## Stretch &mdash; optionalStop here if you like; the required part is done and nothing below affects anything.These exist so that if you *have* programmed before, I can see that too, and pitch thefirst few weeks accordingly.

# %% [markdown]
# ### Stretch 1 &middot; Ask the table somethingShow only the rows for **February**.

# %%
# your code here

# %% [markdown]
# ### Stretch 2 &middot; A better summaryThe mean was misleading. Compute the **median** of `visits` instead, and say in the cellbelow whether it is a fairer summary here.

# %%
# your code here

# %% [markdown]
# &rarr; *is the median fairer here? why?*

# %% [markdown]
# ### Stretch 3 &middot; Per-staff loadAdd a column `visits_per_staff` = visits &divide; staff, then look at what happens toclinic **C-05**. What does that tell you about dividing by a column you have not checked?

# %%
# your code here

# %% [markdown]
# ---## Submitting1. **File &rarr; Download &rarr; Download .ipynb**2. Open **https://portal.latarak.com/course/ds227/lab/1/submit**3. Sign in with your student number and upload the file.You can re-upload as often as you like before the deadline &mdash; the latest version isthe one kept. If you have not been given a password yet, ask your instructor.
