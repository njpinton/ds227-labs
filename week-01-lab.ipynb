# %% [markdown]
# # DS 227 &middot; Knowledge Discovery in Data &mdash; Week 1 Welcome Lab
# ### Where you're starting from
#
# This is **not a test** and it is **not graded**. It exists so I know what the room
# already knows before Week 2, and so you find out now &mdash; not in Week 6 &mdash; whether
# anything here is unfamiliar.
#
# **How long:** about 30 minutes. **What you need:** a browser. Nothing to install.
#
# Work top to bottom. If a cell does not run, that is information too &mdash; write down what
# it said and move on. Nobody is expected to finish the Stretch section.

# %% [markdown]
# ---
# ## Part 0 &middot; Does this thing work
#
# Click the cell below and press **Shift+Enter**.
#
# You are not expected to understand the code. You are expected to be able to run it.

# %%
import io
import pandas as pd

# A small, deliberately messy, INVENTED dataset. These are not real figures and should
# never be cited — the flaws in it are there on purpose, for you to find.
raw = """clinic,barangay,month,visits,staff
C-01,Lahug,January,412,6
C-02,Mabolo,January,388,5
C-03,Guadalupe,January,1240,6
C-04,Talamban,January,,4
C-05,Banilad,January,455,5
C-01,Lahug,February,430,6
C-02,Mabolo,February,401,5
C-03,Guadalupe,February,97,6
C-04,Talamban,February,362,4
C-05,Banilad,February,449,0
"""

df = pd.read_csv(io.StringIO(raw))
print("Rows:", len(df), " Columns:", list(df.columns))
df

# %% [markdown]
# ---
# ## Part 1 &middot; Look at it properly
#
# Look at the table above before reading on. Take a minute; this is the actual skill.
#
# **Answer here** (double-click to edit):
#
# 1. One clinic has a **missing** value. Which one, and in which column?
#    &rarr; *your answer*
#
# 2. Clinic **C-03** reports 1240 visits in January and 97 in February. Give **two
#    different explanations** that could produce that, one boring and one interesting.
#    &rarr; *your answer*
#
# 3. Clinic **C-05** reports 449 visits in February with **0 staff**. What do you think
#    actually happened?
#    &rarr; *your answer*

# %% [markdown]
# ---
# ## Part 2 &middot; A claim that does not hold
#
# Run the cell, then read the claim under it.

# %%
avg = df["visits"].mean()
print(f"Average monthly visits per clinic: {avg:.1f}")

# %% [markdown]
# > **The claim:** *"Clinics in this area average roughly 470 visits a month, so a new
# > clinic should be resourced for about 470."*
#
# **Answer here:**
#
# 1. Name **one** thing wrong with using this average the way the claim does.
#    &rarr; *your answer*
#
# 2. The average was computed from the `visits` column. One row had no value at all.
#    What did the code do with that row &mdash; and did the claim account for it?
#    &rarr; *your answer*
#
# 3. What would you want to know before repeating this number to someone who will spend
#    money based on it?
#    &rarr; *your answer*

# %% [markdown]
# ---
# ## Part 3 &middot; Frame a question
#
# Half of this course is deciding what a dataset can and cannot answer.
#
# **Answer here:**
#
# 1. Write **one question** this table could honestly answer.
#    &rarr; *your answer*
#
# 2. Write **one question** it looks like it could answer but cannot, and say why.
#    &rarr; *your answer*

# %% [markdown]
# ---
# ## Part 4 &middot; About you
#
# Your background, what you want from the course and what you already know are collected
# **once** on the course portal rather than here, so they are not scattered across twelve
# notebooks:
#
# &rarr; [background questionnaire](https://portal.latarak.com/course/ds227/intake)
#
# It takes a few minutes and you only do it once. Your first lab submission unlocks after
# it is filled in.

# %% [markdown]
# ---
# ## Stretch &mdash; optional
#
# Stop here if you like; the required part is done and nothing below affects anything.
#
# These exist so that if you *have* programmed before, I can see that too, and pitch the
# first few weeks accordingly.

# %% [markdown]
# ### Stretch 1 &middot; Ask the table something
#
# Show only the rows for **February**.

# %%
# your code here

# %% [markdown]
# ### Stretch 2 &middot; A better summary
#
# The mean was misleading. Compute the **median** of `visits` instead, and say in the cell
# below whether it is a fairer summary here.

# %%
# your code here

# %% [markdown]
# &rarr; *is the median fairer here? why?*

# %% [markdown]
# ### Stretch 3 &middot; Per-staff load
#
# Add a column `visits_per_staff` = visits &divide; staff, then look at what happens to
# clinic **C-05**. What does that tell you about dividing by a column you have not checked?

# %%
# your code here

# %% [markdown]
# ---
# ## Submitting
#
# Run the cell below. It uploads this notebook straight from Colab &mdash; nothing to
# download.
#
# You need a **submit token** &mdash; one covers every lab for a month. Open
# [https://portal.latarak.com/student/submit-token](https://portal.latarak.com/student/submit-token), sign in and generate it,
# then add it **once** to Colab's Secrets panel (the &#128273; icon, left sidebar) as
# `LATARAK_TOKEN`. After that the cell reads it automatically, with no prompt. No Secrets
# panel? The cell will just ask, hiding what you type.

# %%
# --- Submit this notebook ------------------------------------------------------
# Colab only. Anywhere else, use the manual route described below this cell.
import getpass, json, urllib.request, urllib.error

PORTAL, COURSE, WEEK = "https://portal.latarak.com", "ds227", 1

try:
    from google.colab import _message
except ImportError:
    raise SystemExit(
        "Not running in Colab. Download this notebook "
        "(File > Download > Download .ipynb) and upload it at "
        "https://portal.latarak.com/course/ds227/lab/1/submit"
    )

# The LIVE notebook, including edits you have not saved yet.
nb = _message.blocking_request("get_ipynb", timeout_sec=90)["ipynb"]

# A month-long token. Store it once in Colab Secrets (key LATARAK_TOKEN) and
# this reads it with no prompt; otherwise it asks and hides what you type.
try:
    from google.colab import userdata
    token = (userdata.get("LATARAK_TOKEN") or "").strip()
except Exception:
    token = ""
if not token:
    token = getpass.getpass("Submit token (hidden as you type): ").strip()

req = urllib.request.Request(
    PORTAL + "/api/labs/" + COURSE + "/submit-notebook",
    data=json.dumps({"week": WEEK, "notebook": nb}).encode(),
    headers={"Content-Type": "application/json", "Authorization": "Bearer " + token},
    method="POST",
)
try:
    with urllib.request.urlopen(req, timeout=120) as r:
        out = json.load(r)
    print("Submitted", out["course"], "week", out["week"], "for", out["student"])
    print(out["cells"], "cells,", out["executed"], "executed")
    print(out["message"])
except urllib.error.HTTPError as e:
    print("Not submitted:", json.loads(e.read()).get("error", e.reason))

# %% [markdown]
# Prefer to do it by hand? **File &rarr; Download &rarr; Download .ipynb**, then go to the
# [Week 1 submission page](https://portal.latarak.com/course/ds227/lab/1/submit) and upload it.
#
# Re-submitting replaces your previous attempt; the most recent version is the one kept.
