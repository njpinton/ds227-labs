# %% [markdown]
# # DS 227 &middot; Knowledge Discovery in Data &mdash; Week 12 Lab
# ## Final Project Workbench
#
# This is your **project workbench**, not a set of exercises. It walks the CRISP-DM arc you
# have practised all term &mdash; understand, prepare, explore, find, communicate &mdash; on
# a dataset of your choice. Fill each section with your own work.
#
# **How long:** this is the project; budget more than one sitting. Commit early, commit
# often.
#
# Replace every `# TODO` with real work, and write your findings in the answer cells.

# %% [markdown]
# ---
# ## Section 1 &middot; Business &amp; data understanding
#
# Start with the question and the data that can answer it. Load it and take an honest
# first look. Edit the cell.

# %%
import pandas as pd

# TODO: load your dataset (CSV / API / SQL / scrape)
# df = pd.read_csv("your_data.csv")

# first look:
# print(df.shape); print(df.head()); print(df.info())

# %% [markdown]
# **Write here:**
#
# - **My question:** *what are you trying to discover?* &rarr; *your answer*
# - **The data:** *source, size, how it was collected.* &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 2 &middot; Data preparation
#
# Handle missing values and outliers, integrate any extra sources, and reduce to what you
# need. Document every choice. Edit the cell.

# %%
# TODO: prepare the data
# print(df.isna().sum())
# df = df.dropna(subset=[...])            # or fill, on purpose
# use the IQR rule to flag outliers, then decide
# print("rows before/after:", ...)

# %% [markdown]
# **Write here:**
#
# - **Missing values & outliers:** *what you found and what you did.* &rarr; *your answer*
# - **Integration / reduction:** *any merges, drops, or aggregation.* &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 3 &middot; Exploratory analysis
#
# Describe one variable at a time, then look at relationships. Let the comparison surface a
# story. Edit the cell.

# %%
import matplotlib.pyplot as plt

# TODO: univariate (describe, histogram) then multivariate (corr, scatter, groupby)
# print(df.describe())
# print(df.corr(numeric_only=True).round(2))

# %% [markdown]
# **Write here:**
#
# - **What the EDA revealed:** *distributions, relationships, surprises.* &rarr; *your answer*
# - **The comparison at the heart of your story:** &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 4 &middot; Findings, ethics &amp; communication
#
# State the finding in one sentence, name its limits, and check you have handled any privacy
# risk. Then make the chart that carries it. Edit the cell.

# %%
import matplotlib.pyplot as plt

# TODO: one clear, labelled, honest chart that carries your finding
# fig, ax = plt.subplots(); ...
# ax.set_title("<a finding, not a variable name>")

# %% [markdown]
# **Write here:**
#
# - **One-sentence finding:** *claim + number + caveat.* &rarr; *your answer*
# - **Limitations:** *sample size, confounders, bias.* &rarr; *your answer*
# - **Privacy check:** *any identifiers removed? any group-of-one figures suppressed?*
#   &rarr; *your answer*
# - **Reproducible?** *under git, `requirements.txt`, runs top to bottom?* &rarr; *your answer*

# %% [markdown]
# ---
# ## Stretch &mdash; optional
#
# Stop here if you like; the required part is done.

# %% [markdown]
# ### Stretch &middot; Polish for presentation
#
# Make the notebook something a stranger could follow: a short markdown intro, every
# chart labelled with a finding-title, and a clean run from a fresh restart (Runtime &rarr;
# Restart and run all).

# %%
# your code here

# %% [markdown]
# ---
# ## Submitting
#
# Run the cell below. It uploads this notebook straight from Colab &mdash; nothing to
# download.
#
# You need a **submit token** &mdash; one covers every lab for a month. Open
# [https://portal.latarak.com/student/submit-token](https://portal.latarak.com/student/submit-token), sign in and generate it,
# then add it **once** to Colab's Secrets panel (the &#128273; icon, left sidebar) as
# `LATARAK_TOKEN`. After that the cell reads it automatically, with no prompt. No Secrets
# panel? The cell will just ask, hiding what you type.

# %%
# --- Submit this notebook ------------------------------------------------------
# Colab only. Anywhere else, use the manual route described below this cell.
import getpass, json, urllib.request, urllib.error

PORTAL, COURSE, WEEK = "https://portal.latarak.com", "ds227", 12

try:
    from google.colab import _message
except ImportError:
    raise SystemExit(
        "Not running in Colab. Download this notebook "
        "(File > Download > Download .ipynb) and upload it at "
        "https://portal.latarak.com/course/ds227/lab/12/submit"
    )

# The LIVE notebook, including edits you have not saved yet.
nb = _message.blocking_request("get_ipynb", timeout_sec=90)["ipynb"]

# A month-long token. Store it once in Colab Secrets (key LATARAK_TOKEN) and
# this reads it with no prompt; otherwise it asks and hides what you type.
try:
    from google.colab import userdata
    token = (userdata.get("LATARAK_TOKEN") or "").strip()
except Exception:
    token = ""
if not token:
    token = getpass.getpass("Submit token (hidden as you type): ").strip()

req = urllib.request.Request(
    PORTAL + "/api/labs/" + COURSE + "/submit-notebook",
    data=json.dumps({"week": WEEK, "notebook": nb}).encode(),
    headers={"Content-Type": "application/json", "Authorization": "Bearer " + token},
    method="POST",
)
try:
    with urllib.request.urlopen(req, timeout=120) as r:
        out = json.load(r)
    print("Submitted", out["course"], "week", out["week"], "for", out["student"])
    print(out["cells"], "cells,", out["executed"], "executed")
    print(out["message"])
except urllib.error.HTTPError as e:
    print("Not submitted:", json.loads(e.read()).get("error", e.reason))

# %% [markdown]
# Prefer to do it by hand? **File &rarr; Download &rarr; Download .ipynb**, then go to the
# [Week 12 submission page](https://portal.latarak.com/course/ds227/lab/12/submit) and upload it.
#
# Re-submitting replaces your previous attempt; the most recent version is the one kept.
